# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('sports.csv')

# %%
df.head()
# Out:
#   Borough Location                Park Location  \
# 0           Queens  Playground for All Children
# 1           Queens  Playground for All Children
# 2           Queens  Playground for All Children
# 3           Queens  Playground for All Children
# 4           Queens  Playground for All Children
#
#                           Sports Played Week Start Date Week End Date  \
# 0  Soccer, Basketball, ultimate Frisbee      04/23/2017    04/22/2017
# 1                            Basketball      04/30/2017    05/06/2017
# 2                                Soccer      05/07/2017    05/13/2017
# 3                           Pillow Polo      05/14/2017    05/20/2017
# 4                            All sports      05/21/2017    05/27/2017
#
#    Sunday's Attendance  Monday's Attendance  Tuesday's Attendance  \
# 0                   25                   20                    30
# 1                  250                   95                   120
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Borough Location        308 non-null    object
#  1   Park Location           308 non-null    object
#  2   Sports Played           308 non-null    object
#  3   Week Start Date         308 non-null    object
#  4   Week End Date           308 non-null    object
#  5   Sunday's Attendance     308 non-null    int64
#  6   Monday's Attendance     308 non-null    int64
#  7   Tuesday's Attendance    308 non-null    int64
#  8   Wednesday's Attendance  308 non-null    int64
#  9   Thursday's Attendance   308 non-null    int64
#  10  Friday's Attendance     308 non-null    int64
#  11  Saturday's Attendance   308 non-null    int64
#  12  Attendance Sum          308 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 31.4+ KB

# %%
df.sample(5)
# Out:
#     Borough Location        Park Location  \
# 178         Brooklyn          Sunset Park
# 174         Brooklyn          Sunset Park
# 225            Bronx  Williamsbridge Oval
# 195         Brooklyn          Sunset Park
# 267         Brooklyn          Sunset Park
#
#                                        Sports Played Week Start Date  \
# 178                                      Field Games      08/21/2017
# 174                                       Basketball      08/21/2017
# 225                Basketball, Soccer, Track & Field      05/20/2018
# 195                                           Soccer      08/25/2017
# 267  Fitness Friday, Soccer, Basketball, Dance,Track      05/21/2018
#
#     Week End Date  Sunday's Attendance  Monday's Attendance  \
# 178    08/21/2017                    0                    6
# 174    08/21/2017                    0                   11
# 225    05/26/2018                    0                   16
# ...

# %%
df_nan = df.isnull().sum()
print(df_nan)
# Out:
# Borough Location          0
# Park Location             0
# Sports Played             0
# Week Start Date           0
# Week End Date             0
# Sunday's Attendance       0
# Monday's Attendance       0
# Tuesday's Attendance      0
# Wednesday's Attendance    0
# Thursday's Attendance     0
# Friday's Attendance       0
# Saturday's Attendance     0
# Attendance Sum            0
# dtype: int64
